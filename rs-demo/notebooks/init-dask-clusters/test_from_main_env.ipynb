# %% [markdown]
# # Initialize all dask clusters from main env (for testing only)

# %%
from resources.dask_clusters.dask_main_env import *

# %%
await init_dask_cluster_cpm2()

# %%
await init_dask_cluster_cpm3()

# %%
await init_dask_cluster_l0()

# %%
await init_dask_cluster_mockup()

# %%
await init_dask_cluster_s1ard()

# %%
await init_dask_cluster_s3olci()

# %%
await init_dask_cluster_staging()
